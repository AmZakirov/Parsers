# %% [markdown]
# Read from file (Drive Google):

# %%
import json
import pandas as pd

# Convert from json to csv
# with open('data.json', encoding='utf-8') as json_file:
#     data = json.load(json_file)
#     df = pd.DataFrame()
#     df = pd.DataFrame.from_dict(data)
#     df.to_csv("ex_data.csv", index=False)

# %%
# pd.read_csv("ex_data.csv")
pd.read_excel("ex_data.xlsx")
# Out:
#            Город                             ФИО      Пол  \
# 0         Казань     Мальцева Аделина Эдуардовна  женский
# 1         Казань   Кашанский Владислав Сергеевич  мужской
# 2         Казань       Сафиева Эльвина Рашитовна  женский
# 3         Казань        Яшина Наталья Викторовна  женский
# 4         Казань       Казимова Татьяна Ивановна  женский
# ..           ...                             ...      ...
# 754  Лениногорск      Миргаязов Артур Витальевич  мужской
# 755  Лениногорск     Голубева ирина Владимировна  женский
# 756  Лениногорск  Ермолаева Александра Андреевна  женский
# 757  Лениногорск   данилова екатерина васильевна  женский
# 758  Лениногорск     миронов алексей анатольевич  мужской
#
#             Дата рождения  Возраст       Телефон                       Email  \
# 0    25 октября 2007 года   15 лет  +79869283823        adelmal777@gmail.com
# 1      1 января 2000 года  23 года  +79964129211     vladkashansky@gmail.com
# 2      1 января 1972 года   51 год  +79393302637             elvinai@mail.ru
# 3      20 марта 1995 года   28 лет  +79199037143    fiery1995angel@gmail.com
# 4     14 января 1993 года   30 лет  +79520409791   tanya.kazimova.93@mail.ru
# ..                    ...      ...           ...                         ...
# 754   21 января 1971 года  52 года   +7559561281   gamirgayazova@sberbank.ru
# 755   18 апреля 1960 года  63 года   +7559562305     golubevaiv.60@yandex.ru
# 756  19 августа 1992 года   31 год  +79173912960  Alexandrasofia2010@mail.ru
# 757      25 мая 1988 года   35 лет  +79375936353           kat-danil@mail.ru
# 758      13 мая 1981 года  42 года  +78559594926         aidanka1980@mail.ru
#
#                                          Должность Желаемая зарплата  \
# 0                             Продавец-консультант         10649 руб
# 1                                    Учитель химии         34834 руб
# 2                                           геолог         64194 руб
# 3                                         Психолог         49763 руб
# 4                                    Бортпроводник         69668 руб
# ..                                             ...               ...
# 754                      токарь, слесарь ремонтник         44786 руб
# 755  экономист,кадровый работник,делопроизводитель         34834 руб
# 756                                       оператор         34834 руб
# 757                                      секретарь         34834 руб
# 758                            разноробочий охрaна       1492875 руб
#
#             Занятость          Образование
# 0           свободный              Среднее
# 1               любой               Высшее
# 2               любой           Два высших
# 3    полная занятость               Высшее
# 4    полная занятость               Высшее
# ..                ...                  ...
# 754  полная занятость  Среднее специальное
# 755  полная занятость               Высшее
# 756         свободный              Среднее
# 757  по выходным дням  Среднее специальное
# 758             любой  Среднее специальное
#
# [759 rows x 11 columns]
